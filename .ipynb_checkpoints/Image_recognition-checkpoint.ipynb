# %% [markdown]
# ## Importing Libraries

# %%
import cv2
from deepface import DeepFace
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Happy Face

# %%
img = cv2.imread("dataset/happy_face.jpeg")[:, :, ::-1]

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.52it/s]

# %%
predictions["dominant_emotion"]
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img[:, :, ::-1], (x,y), (x+w, y+h), (255, 0, 0), 5)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
cv2.putText(img[:, :, ::-1],
           predictions['dominant_emotion'],
           (0, 185),
           font, 5,
           (255, 0, 0),
           5,
           cv2.LINE_4);

# %%
plt.imshow(img)

# %% [markdown]
# ## Sad Face

# %%
img = cv2.imread("dataset/sad_face.jpeg")[:, :, ::-1]

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.76it/s]

# %%
predictions["dominant_emotion"]
# Out:
# 'sad'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img[:, :, ::-1], (x,y), (x+w, y+h), (255, 0, 0), 5)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
cv2.putText(img[:, :, ::-1],
           predictions['dominant_emotion'],
           (0, 185),
           font, 5,
           (255, 0, 0),
           5,
           cv2.LINE_4);

# %%
plt.imshow(img)

# %% [markdown]
# ## Angry Face

# %%
img = cv2.imread("dataset/angry_face.jpeg")[:, :, ::-1]

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.67it/s]

# %%
predictions["dominant_emotion"]
# Out:
# 'angry'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img[:, :, ::-1], (x,y), (x+w, y+h), (255, 0, 0), 5)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
cv2.putText(img[:, :, ::-1],
           predictions['dominant_emotion'],
           (0, 185),
           font, 5,
           (255, 0, 0),
           5,
           cv2.LINE_4);

# %%
plt.imshow(img)

# %% [markdown]
# ## Neutral Face

# %%
img = cv2.imread("dataset/neutral_face.jpeg")[:, :, ::-1]

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.29it/s]

# %%
predictions["dominant_emotion"]
# Out:
# 'neutral'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img[:, :, ::-1], (x,y), (x+w, y+h), (255, 0, 0), 5)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
cv2.putText(img[:, :, ::-1],
           predictions['dominant_emotion'],
           (0, 185),
           font, 5,
           (255, 0, 0),
           5,
           cv2.LINE_4);

# %%
plt.imshow(img)

# %% [markdown]
# ## Surprise Face

# %%
img = cv2.imread("dataset/surprise.jpeg")[:, :, ::-1]

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.18it/s]

# %%
predictions["dominant_emotion"]
# Out:
# 'surprise'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img[:, :, ::-1], (x,y), (x+w, y+h), (255, 0, 0), 5)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
cv2.putText(img[:, :, ::-1],
           predictions['dominant_emotion'],
           (0, 185),
           font, 5,
           (255, 0, 0),
           5,
           cv2.LINE_4);

# %%
plt.imshow(img)

# %% [markdown]
# ## Fear Face

# %%
img = cv2.imread("dataset/fear_face.jpeg")[:, :, ::-1]

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.04it/s]

# %%
predictions["dominant_emotion"]
# Out:
# 'fear'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img[:, :, ::-1], (x,y), (x+w, y+h), (255, 0, 0), 5)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
cv2.putText(img[:, :, ::-1],
           predictions['dominant_emotion'],
           (0, 185),
           font, 5,
           (255, 0, 0),
           5,
           cv2.LINE_4);

# %%
plt.imshow(img)

# %% [markdown]
# ## Disgust Face

# %%
img = cv2.imread("dataset/disgust_face.jpeg")[:, :, ::-1]

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.48it/s]

# %%
predictions["dominant_emotion"]
# Out:
# 'disgust'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img[:, :, ::-1], (x,y), (x+w, y+h), (255, 0, 0), 5)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
cv2.putText(img[:, :, ::-1],
           predictions['dominant_emotion'],
           (0, 185),
           font, 5,
           (255, 0, 0),
           5,
           cv2.LINE_4);

# %%
plt.imshow(img)
